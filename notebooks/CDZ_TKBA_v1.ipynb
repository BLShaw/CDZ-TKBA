# %% [markdown]
# # CDZ

# %%
# !git clone https://github.com/BLShaw/CDZ
# Out:
# Cloning into 'CDZ'...
# remote: Enumerating objects: 3172, done.
# remote: Counting objects: 100% (3172/3172), done.
# remote: Compressing objects: 100% (3144/3144), done.
# remote: Total 3172 (delta 34), reused 3157 (delta 22), pack-reused 0 (from 0)
# Receiving objects: 100% (3172/3172), 16.40 MiB | 22.79 MiB/s, done.
# Resolving deltas: 100% (34/34), done.

# %%
# %cd /content/CDZ
# Out:
# /content/CDZ

# %%
# !python scripts/1_prepare_data.py
# Out:
# === Step 1: Preparing Datasets ===
#
# [MNIST] Checking/Downloading...
# 100% 9.91M/9.91M [00:00<00:00, 17.9MB/s]
# 100% 28.9k/28.9k [00:00<00:00, 477kB/s]
# 100% 1.65M/1.65M [00:00<00:00, 4.50MB/s]
# 100% 4.54k/4.54k [00:00<00:00, 15.4MB/s]
# [MNIST] Processing and saving to .npy...
#   Saved mnist_train: (60000, 1, 28, 28)
#   Saved mnist_test: (10000, 1, 28, 28)
#
# [FSDD] Checking/Downloading...
#   Cloning FSDD to data/fsdd...
# Cloning into 'data/fsdd'...
# remote: Enumerating objects: 4260, done.
# remote: Counting objects: 100% (48/48), done.
# remote: Compressing objects: 100% (40/40), done.
# remote: Total 4260 (delta 25), reused 8 (delta 8), pack-reused 4212 (from 1)
# Receiving objects: 100% (4260/4260), 30.38 MiB | 19.63 MiB/s, done.
# Resolving deltas: 100% (129/129), done.
# [FSDD] Found 3000 files. Generating Spectrograms...
#   Saved fsdd_train: (2700, 1, 64, 64)
#   Saved fsdd_test: (300, 1, 64, 64)

# %%
# !python scripts/2_generate_encodings.py
# Out:
# === Step 2: Generating Encodings ===
#
# [Visual] Processing MNIST...
#   Training Visual AE on full dataset...
# Training Autoencoder on 60000 samples for 100 epochs...
# Epoch [10/100], Loss: 0.0060
# Epoch [20/100], Loss: 0.0044
# Epoch [30/100], Loss: 0.0037
# Epoch [40/100], Loss: 0.0032
# Epoch [50/100], Loss: 0.0029
# Epoch [60/100], Loss: 0.0026
# Epoch [70/100], Loss: 0.0024
# Epoch [80/100], Loss: 0.0023
# Epoch [90/100], Loss: 0.0022
# Epoch [100/100], Loss: 0.0021
#   Generating Visual Encodings...
#
# [Audio] Processing FSDD...
#   Loading 2700 spectrograms from data/spectrograms/train...
#   Loading 300 spectrograms from data/spectrograms/test...
#   Training Audio AE...
# Training Autoencoder on 2700 samples for 150 epochs...
# Epoch [10/150], Loss: 0.0062
# Epoch [20/150], Loss: 0.0046
# Epoch [30/150], Loss: 0.0039
# Epoch [40/150], Loss: 0.0035
# Epoch [50/150], Loss: 0.0032
# Epoch [60/150], Loss: 0.0030
# Epoch [70/150], Loss: 0.0029
# ...

# %%
# !python scripts/3_run_hebbian.py
# Out:
# === Step 3: Running Hebbian Learning ===
# Using device: cuda
# Running for 110000 steps...
# Step 0: V-Nodes=1, A-Nodes=1
# Step 500: V-Nodes=250, A-Nodes=250
# Step 1000: V-Nodes=250, A-Nodes=250
# Step 1500: V-Nodes=250, A-Nodes=250
# Step 2000: V-Nodes=250, A-Nodes=250
# Step 2500: V-Nodes=250, A-Nodes=250
# Step 3000: V-Nodes=250, A-Nodes=250
# Step 3500: V-Nodes=250, A-Nodes=250
# Step 4000: V-Nodes=250, A-Nodes=250
# Step 4500: V-Nodes=250, A-Nodes=250
# Step 5000: V-Nodes=250, A-Nodes=250
# Step 5500: V-Nodes=250, A-Nodes=250
# Step 6000: V-Nodes=250, A-Nodes=250
# Step 6500: V-Nodes=250, A-Nodes=250
# Step 7000: V-Nodes=250, A-Nodes=250
# Step 7500: V-Nodes=250, A-Nodes=250
# Step 8000: V-Nodes=250, A-Nodes=250
# Step 8500: V-Nodes=250, A-Nodes=250
# Step 9000: V-Nodes=250, A-Nodes=250
# Step 9500: V-Nodes=250, A-Nodes=250
# Step 10000: V-Nodes=250, A-Nodes=250
# Step 10500: V-Nodes=250, A-Nodes=250
# Step 11000: V-Nodes=250, A-Nodes=250
# ...

# %%
# !python scripts/4_evaluate.py
# Out:
# === Step 4: Evaluation ===
# Using device: cuda
#
# --- Supervised Evaluation (Linear Probe on Encodings) ---
# Visual Modality Accuracy: 0.9208
# Audio Modality Accuracy: 0.8733
#
# --- Unsupervised Evaluation (Brain Clusters) ---
# Database state restored.
# Mapping visual clusters...
# visual Unsupervised Accuracy: 0.8500 (Clusters: 74)
# Mapping audio clusters...
# audio Unsupervised Accuracy: 0.8533 (Clusters: 14)

# %%
# !python scripts/5_visualize.py
# Out:
# === Step 5: Visualization ===
# Using device: cuda
# Generating t-SNE for Visual Encodings (Test) (t-SNE)...
# Saved to data/plots/visual_test_tsne.png
# Generating t-SNE for Visual Encodings (Train) (t-SNE)...
# Saved to data/plots/visual_train_tsne.png
# Generating t-SNE for Audio Encodings (Test) (t-SNE)...
# Saved to data/plots/audio_test_tsne.png
# Generating t-SNE for Audio Encodings (Train) (t-SNE)...
# Saved to data/plots/audio_train_tsne.png

# %%
from IPython.display import Image, display

image_paths = [
    "/content/CDZ/data/plots/visual_train_tsne.png",
    "/content/CDZ/data/plots/visual_test_tsne.png",
    "/content/CDZ/data/plots/audio_train_tsne.png",
    "/content/CDZ/data/plots/audio_test_tsne.png"
]

for path in image_paths:
    print(f"Displaying: {path}")
    display(Image(filename=path))
# Out:
# Displaying: /content/CDZ/data/plots/visual_train_tsne.png
# Displaying: /content/CDZ/data/plots/visual_test_tsne.png
# Displaying: /content/CDZ/data/plots/audio_train_tsne.png
# Displaying: /content/CDZ/data/plots/audio_test_tsne.png

# %% [markdown]
# ---

# %%
# !python scripts/3_run_hebbian.py
# Out:
# === Step 3: Running Hebbian Learning ===
# Using device: cuda
# Running for 110000 steps...
# Step 0: V-Nodes=1, A-Nodes=1
# Step 500: V-Nodes=325, A-Nodes=402
# Step 1000: V-Nodes=550, A-Nodes=655
# Step 1500: V-Nodes=726, A-Nodes=861
# Step 2000: V-Nodes=891, A-Nodes=993
# Step 2500: V-Nodes=1030, A-Nodes=1110
# Step 3000: V-Nodes=1184, A-Nodes=1192
# Step 3500: V-Nodes=1303, A-Nodes=1274
# Step 4000: V-Nodes=1417, A-Nodes=1336
# Step 4500: V-Nodes=1543, A-Nodes=1384
# Step 5000: V-Nodes=1675, A-Nodes=1424
# Step 5500: V-Nodes=1782, A-Nodes=1461
# Step 6000: V-Nodes=1868, A-Nodes=1492
# Step 6500: V-Nodes=1951, A-Nodes=1518
# Step 7000: V-Nodes=2042, A-Nodes=1542
# Step 7500: V-Nodes=2116, A-Nodes=1553
# Step 8000: V-Nodes=2203, A-Nodes=1563
# Step 8500: V-Nodes=2278, A-Nodes=1579
# Step 9000: V-Nodes=2360, A-Nodes=1595
# Step 9500: V-Nodes=2423, A-Nodes=1597
# Step 10000: V-Nodes=2490, A-Nodes=1601
# Step 10500: V-Nodes=2558, A-Nodes=1607
# Step 11000: V-Nodes=2616, A-Nodes=1613
# ...

# %%
# !python scripts/4_evaluate.py
# Out:
# === Step 4: Evaluation ===
# Using device: cuda
#
# --- Supervised Evaluation (Linear Probe on Encodings) ---
# Visual Modality Accuracy: 0.9208
# Audio Modality Accuracy: 0.8733
#
# --- Unsupervised Evaluation (Brain Clusters) ---
# Database state restored.
# Mapping visual clusters...
# visual Unsupervised Accuracy: 0.8206 (Clusters: 1711)
# Mapping audio clusters...
# audio Unsupervised Accuracy: 0.8567 (Clusters: 170)

# %%
# !python scripts/5_visualize.py
# Out:
# === Step 5: Visualization ===
# Using device: cuda
# Generating t-SNE for Visual Encodings (Test) (t-SNE)...
# Saved to data/plots/visual_test_tsne.png
# Generating t-SNE for Visual Encodings (Train) (t-SNE)...
# Saved to data/plots/visual_train_tsne.png
# Generating t-SNE for Audio Encodings (Test) (t-SNE)...
# Saved to data/plots/audio_test_tsne.png
# Generating t-SNE for Audio Encodings (Train) (t-SNE)...
# Saved to data/plots/audio_train_tsne.png

# %%
from IPython.display import Image, display

image_paths = [
    "/content/CDZ/data/plots/visual_train_tsne.png",
    "/content/CDZ/data/plots/visual_test_tsne.png",
    "/content/CDZ/data/plots/audio_train_tsne.png",
    "/content/CDZ/data/plots/audio_test_tsne.png"
]

for path in image_paths:
    print(f"Displaying: {path}")
    display(Image(filename=path))
# Out:
# Displaying: /content/CDZ/data/plots/visual_train_tsne.png
# Displaying: /content/CDZ/data/plots/visual_test_tsne.png
# Displaying: /content/CDZ/data/plots/audio_train_tsne.png
# Displaying: /content/CDZ/data/plots/audio_test_tsne.png
